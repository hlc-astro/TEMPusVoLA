# %% [markdown]
# We would like to estimate the size and time scales of the instability that may develop at the interface between a dust-laden and dust-free gas. We take the result from the linear stability analysis of the Kelvin-Helmholtz instability, which has the following dispersion relation:
#
# The real part, $\omega_r/k_{x}=\frac{\rho_{1}v_{1}+\rho_{1}v_{1}}{\rho_{1}+\rho_{2}}$
#
# and the quadratic term has a positive growth rate as long as there is a velocity difference between the two phases:
#
# $\sigma/k_{x}=(v_{1}-v_{2})\frac{(\rho_{1}\rho_{2})^{1/2}}{\rho_{1}+\rho_{2}}$
#
#
# This gives us a simple way to estimate the wavelengths at which the growth is fastest. However, we note that the velocity and the density are coupled, since in the absence of gravity, the only way to slow the gas phase by the particles is by the collective effect of the mass-loaded two-phase flow. So we first estimate the extent to which the flow can be slowed by a particle phase of a given concentration by evolving the two-fluid equations without external force (and for now, neglecting viscosity!). To do so, I use the Euler approach in one dimension, that is, approximating the change in velocity of either the particles or the gas at each time step by summing it's derivative.
#
# So that the gas velocity, initially 1 m/s, evolves for each time $t_{i}$ as:
#
# $v_{gas}(t_{i+1})= v_{gas}(t_{i})+\frac{\epsilon}{t_{f}}[v_{dust}(t_{i})-v_{gas}(t_{i})]dt$
#
# and the particle velocity, initially with 0 m/s, evolves for each time $t_{i}$ as:
#
# $v_{dust}(t_{i+1})= v_{gas}(t_{i})-\frac{1}{t_{f}}[v_{dust}(t_{i})-v_{gas}(t_{i})]dt$
#
# The velocities of these two coupled phases are essentially symmetric, except the gas phase is controled by the dust to gas ratio, $\epsilon=\phi \rho_{p}/\rho_{g}$. Note that the filling factor $\phi$ depends strongly on particle size, as $\phi=\pi/6.0 N d_{p}^{3}$, where N is the number of particles of given size per unit volume (assumed to be 1 million, here $d_{p}$ assumed to be 15 micrometers. The densities of the particles are that of rock, 3000 Kg m$^{-3}$, and the gas density can be varried to change $\epsilon$.

# %%
from IPython.display import Image
Image(filename='v_rel_10mbar.png')

# %% [markdown]
# As expected, within e friction times, the gas accelerates the particles, and the particles decelerate the gas, so that they approach the same speed, which is about 90% of the original gas velocity. In this case, the mass loading is 0.05 and the stopping time is 0.30 seconds. Therefore, we do not expect the gas to become streaming unstable. We also expect the flow to travel just under 30 cm before the particle-laden phase has a significant relative velocity with respect to the adjacent particle-free phase. Taking the long-time value of the gas & dust velocity, we can now use this to calculate investigate the development of the fastest growing wavenumbers, which are related to the wavelength by $k_{x}=\frac{2\pi}{\lambda}$.

# %%
Image(filename='dispersion_10mbar.png')

# %% [markdown]
# Both the real (left side) and imaginary (right side) parts of the dispersion relation are dominated by the wavenumber dependence. We see that the highest frequency wave modes have the highest grow rates and correspond to the shortest wavelengths. Perhaps this is encouraging, since we could then resolve the smaller structures in our measurements. Note that there being a relative velocity depends upon the mass-loading and this is set by the pressure. By raising the pressure to 100 mbar, we would lower the mass-loading and therefore a relative velocity would not develop. However, if we go too low
